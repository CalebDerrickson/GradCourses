# %%
from typing import Tuple, Dict, Hashable

import numpy as np
import networkx as nx
import matplotlib as mpl
import matplotlib.pyplot as plt

colors = np.array(['tab:blue', 'orange'])

# %%
def compute_cut_score(G: nx.graph, S: nx.Graph):
    """
    Returns the cut score for the subgraph S of the Graph G.

    \phi(S) = w(E(S, \bar{S})) / min(vol(S), vol(\bar{S}))
    """
    
    #Taking min of vol(S),vol(\bar{S})
    Vol_G = nx.volume(G, G.nodes())
    Vol_S = nx.volume(S, S.nodes())
    
    if Vol_G == Vol_S:
        #No cut happened, return 0
        print("No cut happened")
        return np.nan
    
    if Vol_S >= Vol_G/2:
        vol = Vol_G - Vol_S
    else:
        vol = Vol_S
        
    #Getting the weights of edges on the boundary of S and summing them
    bound_edges = nx.edge_boundary(G, S.nodes())
    bound_weights = sum(list([G[edge[0]][edge[1]]["weight"] for edge in bound_edges]))
    
    if bound_weights == 0:
        #Cutting nothing...
        return np.nan
    
    res = bound_weights / vol
    print(f'Cut: {Vol_S} Volume: {vol} Weight Sum: {bound_weights} Score: {res}')
    return res

# %%
def sweep_cut(G: nx.Graph, x: np.ndarray) -> (float, float, np.ndarray):
    """Sweep Cut
    
    Also known as threshold cut, takes in a graph and a
    1D embedding of the nodes and returns a threshold,
    the conductance from the associated threshold cut and
    a 0/1 vector indicating which side of the cut each node
    belongs to in the best conductance cut.
    
    Parameters
    ----------
    G : nx.Graph
        The graph to compute the threshold cut for.
    x : np.ndarray
        1D Embedding of the nodes in G.
        
    Returns
    -------
    thr : float
        The best conductance threshold.
    conductance : float
        Conductance \phi(S) = w(E(S, \bar{S})) / min(vol(S), vol(\bar{S}))
        of the best threshold cut
    cut : np.ndarray
        0/1 indicator vector of the best threshold cut.
        It holds that cut = (x <= thr)
    """
    n = len(G)
    # TODO: Compute the threshold for best conductance cut
    #
    #       \phi(S) = w(E(S, \bar{S})) / min(vol(S), vol(\bar{S}))
    #
    #       Your code should take advantage of the fact that
    #       the difference between two adjacent threshold cuts
    #       is a single node. Total running time should be O(|V| + |E|).
    
    """
    Method to solve:
    ----------------
    1) Compute the Fidler vector, v_2 (eigenvector of second eigenvalue)
    2) Sort v_2 from least to greatest value
    3) Consider cuts between successive components of sorted v_2
        - Compute the cut for each pair of components
    4) Choose the threshold that delivers the the smallest cut
    """

        
    if len(x.shape) != 1:
        raise ValueError(f'Embedding should be one dimensional. Instead got `x` with shape {x.shape}.')
        
    #Getting 2nd Eigenvector of the Laplacian of G, which is returned sparse by networkx
    L = nx.laplacian_matrix(G).toarray()
    v_2 = np.linalg.eigh(L)[1][:, 1]
    
    #Array of cut scores
    cut_arr = np.zeros(len(v_2) - 1)
    cut_arr[:] = np.nan
    
    
    #Sort v_2, want the argument list. Don't care about stability, just speed
    v_2_arg = np.argsort(v_2, kind='heapsort')

    #Introduce subgraph S
    S = nx.Graph()
    
    
    #Incrementally add to S, using the nodes of the indices in v_2_arg
    for i in range(len(v_2_arg) - 1):
        S.add_node(v_2_arg[i])
        S.add_edges_from(G.edges(v_2_arg[i]))

        #Compute cut score for S
        cut_arr[i] = compute_cut_score(G, S)
        
    
    print(f'Cut array: {cut_arr}')
    plt.scatter(range(0, len(cut_arr)), cut_arr)
    plt.grid(True)
    thr = x.min()
    conductance = np.inf
    cut = np.zeros(n, int)
    
    return thr, conductance, cut

# %%
n = 20
P = nx.karate_club_graph()
nx.set_edge_attributes(P, 1, 'weight')
x = np.linspace(0, 1, n)
thr, cond, cut = sweep_cut(P, x)

#print(f'On the path with {n} nodes the best conductance threshold is thr = {thr:.6f} and yields conductance {cond:.6f}.')
#pos = nx.spectral_layout(P)
#nx.draw(P, pos=pos, node_color=colors[cut], node_size=50)
# Out:
# Cut: 4 Volume: 4 Weight Sum: 4 Score: 1.0
# Cut: 10 Volume: 10 Weight Sum: 15 Score: 1.5
# Cut: 14 Volume: 14 Weight Sum: 12 Score: 0.8571428571428571
# Cut: 18 Volume: 18 Weight Sum: 12 Score: 0.6666666666666666
# Cut: 20 Volume: 20 Weight Sum: 12 Score: 0.6
# Cut: 22 Volume: 22 Weight Sum: 11 Score: 0.5
# Cut: 44 Volume: 44 Weight Sum: 15 Score: 0.3409090909090909
# Cut: 46 Volume: 46 Weight Sum: 15 Score: 0.32608695652173914
# Cut: 48 Volume: 48 Weight Sum: 15 Score: 0.3125
# Cut: 50 Volume: 50 Weight Sum: 15 Score: 0.3
# Cut: 58 Volume: 58 Weight Sum: 15 Score: 0.25862068965517243
# Cut: 62 Volume: 62 Weight Sum: 15 Score: 0.24193548387096775
# Cut: 70 Volume: 70 Weight Sum: 15 Score: 0.21428571428571427
# Cut: 74 Volume: 74 Weight Sum: 22 Score: 0.2972972972972973
# Cut: 76 Volume: 76 Weight Sum: 22 Score: 0.2894736842105263
# Cut: 86 Volume: 70 Weight Sum: 19 Score: 0.2714285714285714
# Cut: 92 Volume: 64 Weight Sum: 19 Score: 0.296875
# Cut: 96 Volume: 60 Weight Sum: 19 Score: 0.31666666666666665
# Cut: 98 Volume: 58 Weight Sum: 19 Score: 0.3275862068965517
# Cut: 102 Volume: 54 Weight Sum: 19 Score: 0.35185185185185186
# Cut: 110 Volume: 46 Weight Sum: 17 Score: 0.3695652173913043
# No cut happened
# Cut array: [1.         1.5        0.85714286 0.66666667 0.6        0.5
#  0.34090909 0.32608696 0.3125     0.3        0.25862069 0.24193548
#  0.21428571 0.2972973  0.28947368 0.27142857 0.296875   0.31666667
#  0.32758621 0.35185185 0.36956522        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
